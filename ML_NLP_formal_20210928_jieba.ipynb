# %% [markdown]
# <a href="https://colab.research.google.com/github/Whaleman0423/Tibame_machine_learning0922/blob/main/ML_NLP_formal_20210928_jieba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 簡繁統一 => opencc-python
# !pip install opencc-python-reimplemented
# Out:
# ...
#      |████████████████████████████████| 484 kB 5.2 MB/s
# ...
#   Created wheel for opencc-python-reimplemented: filename=opencc_python_reimplemented-0.1.6-py2.py3-none-any.whl size=486150 sha256=c50de48dfedcaf96dda75bad096ae238fcb9425a701f4a0726edbf3c8c3aacc2
#   Stored in directory: /root/.cache/pip/wheels/4e/e2/60/d062d260be08788bb389521544a8fc173de9a9a78d6a593344
# Successfully built opencc-python-reimplemented
# ...

# %%
from opencc import OpenCC
cc = OpenCC('s2tw') 
to_convert = """繁体中文。
为什么会觉得烦呢？也许让我们学写繁体中文的话，我们可能会烦。
主要看所处的环境。
如果楼主从一出生就学的是繁体中文的话，现在让你学写简体中文，你也会烦的。如果一个英语为母语的国家，让他们的人民学中文，不管是繁体还是简体都会烦。
要你用你的纯母语来书写，应该是最顺手的吧"""
converted = cc.convert(to_convert)
converted
# Out:
# '繁體中文。\n為什麼會覺得煩呢？也許讓我們學寫繁體中文的話，我們可能會煩。\n主要看所處的環境。\n如果樓主從一出生就學的是繁體中文的話，現在讓你學寫簡體中文，你也會煩的。如果一個英語為母語的國家，讓他們的人民學中文，不管是繁體還是簡體都會煩。\n要你用你的純母語來書寫，應該是最順手的吧'

# %%
article = """第56金鐘2日晚間落幕，藝人炎亞綸獲頒綜藝節目主持人獎，一席得獎感言「我要感謝我生長在一個讓思想可以自由奔放的地方，我相信我們有無比光明的前途，加油！」感動不少觀眾。對此，總統蔡英文在臉書發文祝賀，她表示，這可能是很多創作者的心聲，「我們也會繼續捍衛多元自由的創作環境，因為這是培養出優質電視廣播作品的沃土」。

蔡英文在臉書發文恭喜所有金鐘得獎者，並感謝所有廣播人、電視人，疫情當前，依然堅守崗位，持續製作出優質的內容，帶給大家很多不一樣的啟發和感動。

蔡英文提及，炎亞綸在得獎感言中提到，感謝在台灣能夠有自由奔放的思想。「我想，這可能是很多創作者的心聲，我們也會繼續捍衛多元自由的創作環境，因為這是培養出優質電視廣播作品的沃土」，台灣的影音創作需要一代又一代的新血投入，要把掌聲獻給所有廣播電視人，讓全民繼續支持台灣的好人才、好內容。

民進黨籍基隆市議員張之豪也有感表示，炎亞綸，一個最初出身自偶像團體飛輪海的藝人，當初出道時，應該沒有想到自己有一天會因為這句話而名留台灣的歷史上。他的這句話，說的是自由的台灣，而且是很具體的，「台灣這個自由的社會」。這句話的背面，對應的，是前天眾多滯留中國，為中國祝賀國慶的台籍藝人。在別人的土地上討生活，也許有外人無法理解的苦衷，比方半年賺了3億的歐陽娜娜。

張之豪指出，試著在中國叫共產黨「塔紅班」，就試試、感受看看，社會主義鐵拳的滋味會有多香。但當然，在自由的台灣，不會有人逼你這麼做，所有的國家的公權力，都受到箝制與監督，施政者更是如履薄冰地治理國家，這就是自由社會的基石，而我們盡全力在保護這件事。"""

# %%
import jieba
# 下載資料
from urllib.request import urlretrieve
url = "https://github.com/fxsjy/jieba/raw/master/extra_dict/dict.txt.big"
urlretrieve(url, "dict.txt.big")
# list(jieba.cut(article))
jieba.set_dictionary("dict.txt.big") # 載入大字典
jieba.load_userdict("extra.txt") # 載入自定義詞的字典
" ".join(jieba.cut(article))
# Out:
# Building prefix dict from /content/dict.txt.big ...
# Dumping model to file cache /tmp/jieba.u501edca284da514cb68b53a20324f4e3.cache
# Loading model cost 1.801 seconds.
# Prefix dict has been built successfully.
# ...

# %%
import jieba.analyse
# jieba.analyse.extract_tags(article, topK=None, withWeight=True, allowPOS=["n"])
jieba.analyse.extract_tags(article, topK=None, withWeight=True)
# Out:
# [('台灣', 0.3719261000902222),
#  ('自由的', 0.26566150006444444),
#  ('我們', 0.21252920005155554),
#  ('藝人', 0.15939690003866666),
#  ('炎亞綸', 0.15939690003866666),
#  ('感謝', 0.15939690003866666),
#  ('蔡英文', 0.15939690003866666),
#  ('繼續', 0.15939690003866666),
#  ('創作', 0.15939690003866666),
#  ('因為', 0.15939690003866666),
#  ('優質', 0.15939690003866666),
#  ('這句', 0.15939690003866666),
#  ('中國', 0.15939690003866666),
#  ('金鐘', 0.10626460002577777),
#  ('得獎', 0.10626460002577777),
#  ('一個', 0.10626460002577777),
#  ('感動', 0.10626460002577777),
#  ('臉書', 0.10626460002577777),
#  ('發文', 0.10626460002577777),
#  ('祝賀', 0.10626460002577777),
#  ('創作者', 0.10626460002577777),
#  ('心聲', 0.10626460002577777),
#  ('捍衛', 0.10626460002577777),
#  ('環境', 0.10626460002577777),
#  ('這是', 0.10626460002577777),
#  ('培養', 0.10626460002577777),
#  ('電視廣播', 0.10626460002577777),
#  ('內容', 0.10626460002577777),
#  ('張之豪', 0.10626460002577777),
#  ('社會', 0.10626460002577777),
#  ('國家', 0.10626460002577777),
# ...
